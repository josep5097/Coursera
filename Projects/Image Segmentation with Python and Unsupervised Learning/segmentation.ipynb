# %% [markdown]
# Image Segmentation with Python and Unsupervised Learning
# ========================================================

# %% [markdown]
# ![image](images/butterfly.jpg)
#
# Import libraries.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# Load image from file and display it.

# %%
img = cv2.imread("images/butterfly.jpg")
print("tipo: " + str(type(img)))
print("Shape:" + str(img.shape))
# Out:
# tipo: <class 'numpy.ndarray'>
# Shape:(425, 640, 3)

# %% [markdown]
# Display image.

# %%
cv2.imshow("Frame", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Flatten image, and display in 3-D color space.

# %%
flat = np.reshape(img, (-1,3))
colors = flat [:,[2,1,0]]/255.0

fig  = plt.figure()
ax = Axes3D(fig)
ax.scatter(
    flat[:,0 ],
    flat[:,1 ],
    flat[:,2 ],
    c = colors,
    marker = "."
)
ax.set_xlabel("Blue")
ax.set_ylabel("Green")
ax.set_zlabel("Red")

plt.show()
plt.clf()
plt.close()

# %%
idx =  np.random.choice(flat.shape[0],5000)
sampled_flat = flat[idx]
colors = sampled_flat [:,[2,1,0]]/255.0

fig  = plt.figure()
ax = Axes3D(fig)
ax.scatter(
    sampled_flat[:,0 ],
    sampled_flat[:,1 ],
    sampled_flat[:,2 ],
    c = colors,
    marker = "."
)
ax.set_xlabel("Blue")
ax.set_ylabel("Green")
ax.set_zlabel("Red")

plt.show()
plt.clf()
plt.close()

# %% [markdown]
# K-means.

# %%
k = 5
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 250,1.0) #minimal accuracy - Epsilon and maximum number of iterations
ssd, bestLabels, centers = cv2.kmeans(
    data = flat.astype(np.float32),
    K = k,
    bestLabels = None,
    criteria = criteria,
    attempts = 10,
    flags = cv2.KMEANS_RANDOM_CENTERS
)

# %% [markdown]
# Plotting cluster centers in RGB space.

# %%
colors = centers [:,[2,1,0]]/255.0

fig  = plt.figure()
ax = Axes3D(fig)
ax.scatter(
    centers[:,0 ],
    centers[:,1 ],
    centers[:,2 ],
    c = colors,
    marker = "X",
    s = 500
)
ax.set_xlabel("Blue")
ax.set_ylabel("Green")
ax.set_zlabel("Red")

plt.show()
plt.clf()
plt.close()

# %% [markdown]
# Plot segmented image.

# %%
centers = centers.astype(np.uint8)
print(centers)
print(bestLabels)

segmented_flat = centers[bestLabels]

segmented_image = segmented_flat.reshape(img.shape)

cv2.imshow("Frame", segmented_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[  7  97 208]
#  [ 89 148 173]
#  [ 24  71 100]
#  [ 63 186 249]
#  [  6  29  36]]
# [[4]
#  [4]
#  [4]
#  ...
#  [4]
#  [4]
#  [4]]

# %% [markdown]
# Elbow method.

# %%
Ks = []
distances = []

criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 250,1.0) #minimal accuracy - Epsilon and maximum number of iterations

for K in range(2,16):
    ssd, bestLabels, centers = cv2.kmeans(
        data = flat.astype(np.float32),
        K = K,
        bestLabels = None,
        criteria = criteria,
        attempts = 10,
        flags = cv2.KMEANS_RANDOM_CENTERS
    )
    Ks.append(K)
    distances.append(ssd)
plt.plot(Ks, distances)
plt.show()

# %%
K = 6
ssd, bestLabels, centers = cv2.kmeans(
    data = flat.astype(np.float32),
    K = K,
    bestLabels = None,
    criteria = criteria,
    attempts = 10,
    flags = cv2.KMEANS_RANDOM_CENTERS
)
Ks.append(K)
distances.append(ssd)
