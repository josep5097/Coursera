# %% [markdown]
# # Introduction to Deep Learning and Neural Network with Keras
#
# **Final work**
#
# **Ing. José Miguel Pereira Pontón**
#
#
# # Instructions - Part A:
# A. Build a baseline model (5 marks)
#
# Use the Keras library to build a neural network with the following:
#
# - One hidden layer of 10 nodes, and a ReLU activation function
#
# - Use the adam optimizer and the mean squared error  as the loss function.
#
# 1. Randomly split the data into a training and test sets by holding 30% of the data for testing. you can use the train_test_splithelper function from Scikit-learn.
#
# 2. Train the model on the training data using 50 epochs.
#
# 3. Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. you can use the mean_squared_error function from Scikit-learn.
#
# 4. Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.
#
# 5. Report the mean and the standard deviation of the mean squared errors.
#
# # Instructions - Part B:
# 6. Repeat Part A but use a normalized version of the data. Recall that one way to normalize the data is by subtracting the mean from the individual predictors and dividing by the standard deviation.
#
# # Instructions - Part C:
#
# **Increate the number of epochs (5 marks)**
#
# 7. Repeat Part B but use 100 epochs this time for training.
#
# # Instructions - Part D
#
# **Increase the number of hidden layers (5 marks)**
#
# Repeat part B but use a neural network with the following instead:
#
# - Three hidden layers, each of 10 nodes and ReLU activation function.

# %% [markdown]
# # Preparing the environment
#
# Import some libraries

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import pandas as pd
import numpy as np

# %% [markdown]
# Read the data set

# %%
concrete_data = pd.read_csv('concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# Split dataset into inputs(predictors) and y (target)

# %%
# First: Split dataset into input (x) and output (y) variables
# Obtain the columns
concrete_data_columns = concrete_data.columns
# Selecting all columns except Strength
x = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] 
# Strength column
y = concrete_data['Strength']

# %%
# Lets do some review of information of predictors
x.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
# Lets do some review of information of target
y.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %%
# Finally normalizing the data by substracting the mean and dividing by the standard deviation
x_norm = (x-x.mean())/x.std()

# %%
# Number of predictors
n_cols = x.shape[1]

# %% [markdown]
# Using the model from Part A, but with a modification on the hidden layer
#
# We use 3 hidden layers of 10 nodes and and ReLU Activation Function.

# %%
# Defining a function for regression model
def regression_model():
    # create model
    model = Sequential()
    # First layer
    model.add(Dense(7, activation='relu',input_shape=(n_cols,)))
    # Hiden Layer
    model.add(Dense(10, activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

model = regression_model()

# %% [markdown]
# 1. Randomly split the data into a training and test sets by holding 30% of the data for testing. You can use the train_test_split helper function from Scikit-learn.

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_norm, y, test_size=0.3, random_state=23)
# let's have a look at the shape of the predictors set
x_train.shape
# Out:
# (721, 8)

# %% [markdown]
# 2. Train the model on the training data using 50 epochs.

# %%
model.fit(x_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 0s 607us/step - loss: 1535.3726
# Epoch 2/50
# 23/23 [==============================] - 0s 477us/step - loss: 1519.7361
# Epoch 3/50
# 23/23 [==============================] - 0s 475us/step - loss: 1496.8033
# Epoch 4/50
# 23/23 [==============================] - 0s 607us/step - loss: 1455.9669
# Epoch 5/50
# 23/23 [==============================] - 0s 607us/step - loss: 1380.1123
# Epoch 6/50
# 23/23 [==============================] - 0s 630us/step - loss: 1243.7203
# Epoch 7/50
# 23/23 [==============================] - 0s 650us/step - loss: 1024.6709
# Epoch 8/50
# 23/23 [==============================] - 0s 607us/step - loss: 717.0242
# Epoch 9/50
# 23/23 [==============================] - 0s 607us/step - loss: 424.5437
# Epoch 10/50
# 23/23 [==============================] - 0s 651us/step - loss: 285.3130
# Epoch 11/50
# 23/23 [==============================] - 0s 694us/step - loss: 253.6864
# Epoch 12/50
# ...

# %% [markdown]
# 3. Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. you can use the mean_squared_error function from Scikit-learn.

# %%
y_pred = model.predict(x_test)
from sklearn.metrics import mean_squared_error
print('Mean squared error on test data is %.3f' % (mean_squared_error(y_test, y_pred)))
# Out:
# Mean squared error on test data is 117.858

# %% [markdown]
# 4. Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.
# 5. Report the mean and the standard deviation of the mean squared errors.

# %%
mse = []
for i in range(50):
    model = regression_model()
    model.fit(x_train, y_train, epochs=50)
    y_pred = model.predict(x_test)
    mse.append(mean_squared_error(y_test, y_pred))
# Out:
# Epoch 1/50
# 23/23 [==============================] - 0s 607us/step - loss: 1550.1378
# Epoch 2/50
# 23/23 [==============================] - 0s 434us/step - loss: 1521.2924
# Epoch 3/50
# 23/23 [==============================] - 0s 504us/step - loss: 1486.1775
# Epoch 4/50
# 23/23 [==============================] - 0s 684us/step - loss: 1433.2742
# Epoch 5/50
# 23/23 [==============================] - 0s 603us/step - loss: 1349.7233
# Epoch 6/50
# 23/23 [==============================] - 0s 607us/step - loss: 1218.1007
# Epoch 7/50
# 23/23 [==============================] - 0s 607us/step - loss: 1012.7372
# Epoch 8/50
# 23/23 [==============================] - 0s 564us/step - loss: 742.7896
# Epoch 9/50
# 23/23 [==============================] - 0s 607us/step - loss: 480.9917
# Epoch 10/50
# 23/23 [==============================] - 0s 650us/step - loss: 330.6269
# Epoch 11/50
# 23/23 [==============================] - 0s 564us/step - loss: 266.3057
# Epoch 12/50
# ...

# %% [markdown]
# 5. Report the mean and the standard deviation of the mean squared errors.

# %%
mean = np.mean(mse)
mean
# Out:
# 114.43287273930177

# %%
std = np.std(mse)
std
# Out:
# 18.523912884245586

# %%
print("Mean squared errors for 50 regression models: mean = %.3f, std dev = %.3f" %(mean, std))
# Out:
# Mean squared errors for 50 regression models: mean = 114.433, std dev = 18.524

# %% [markdown]
# How does the mean of the mean squared errors compare to that from Step B?
#
# In Step B, I record a MSE of 159.145 and in Part D I record a MSE of 117.858, we can notice that in Part B, we had only 1 hidden layer and in Part D we have 3 hidden layers. The number of hidden layers improve the result
#
# And if we review the MSE of the 50 regression model of Part A, B and D, and 100 regression model of Part C:
#
# |--- |Part A | Part B| Part C | Part D |
# | --- | ---- | --- | --- | --- |
# |**MSE**|203.422 | 151.077| 110.776 | 114.432 |
# | **STD** | 206.667 | 10.433| 13.230 | 18.523 |
#
# When we analyze the mean and standard deviation of multiple regression models, we can notice that in Part D, compared to Part B, the MSE was better but the STD increased.
#
# And if we compared to part C what was similar but with less hidden layers, and more Epochs. Part D obtained poor results, MSE was 4 points more and the STD increased, but compared to Part B, is a better model.
#
# We can obtain better fitting for the model but the time to process the data increase too.
#
# If I have to decided what model implement, I would choose the model in Part C.
#
# **End of Part D.**
