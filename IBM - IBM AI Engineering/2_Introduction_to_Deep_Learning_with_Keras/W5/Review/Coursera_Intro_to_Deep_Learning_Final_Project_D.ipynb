# %%
import pandas as pd
import numpy as np

# %%
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
#Splitting the data
predictors = concrete_data[['Cement', 'Blast Furnace Slag', 'Fly Ash', 'Water', 'Superplasticizer', 'Coarse Aggregate', 'Fine Aggregate', 'Age', 'Strength']]
target = concrete_data['Strength']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/utils/validation.py:37: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   LARGE_SPARSE_SUPPORTED = LooseVersion(scipy_version) >= '0.14.0'

# %%
n_cols = predictors.shape[1]

# %%
#PART D
#Mean of MSE (part c):  0.8712325226151825
#Standard Deviation of MSE (part c): 5.269090978358493

# %%
#Adding more hidden layers to the neural network
def regression_model_2():
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1))
    
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

model = regression_model_2()

# %%
model.fit(X_train, y_train, validation_split=0.3, epochs=50, verbose=2)
# Out:
# Train on 504 samples, validate on 217 samples
# Epoch 1/50
#  - 0s - loss: 51895.8066 - val_loss: 24469.8396
# Epoch 2/50
#  - 0s - loss: 13262.3787 - val_loss: 3985.5416
# Epoch 3/50
#  - 0s - loss: 1785.0017 - val_loss: 1125.8538
# Epoch 4/50
#  - 0s - loss: 990.2936 - val_loss: 661.0070
# Epoch 5/50
#  - 0s - loss: 548.4379 - val_loss: 494.3061
# Epoch 6/50
#  - 0s - loss: 436.5987 - val_loss: 386.4379
# Epoch 7/50
#  - 0s - loss: 348.7014 - val_loss: 321.2237
# Epoch 8/50
#  - 0s - loss: 291.5602 - val_loss: 279.2707
# Epoch 9/50
#  - 0s - loss: 257.4151 - val_loss: 248.1016
# Epoch 10/50
#  - 0s - loss: 228.5235 - val_loss: 227.9693
# Epoch 11/50
#  - 0s - loss: 209.8722 - val_loss: 213.4166
# Epoch 12/50
#  - 0s - loss: 198.2158 - val_loss: 201.9803
# Epoch 13/50
#  - 0s - loss: 186.9781 - val_loss: 194.5952
# Epoch 14/50
#  - 0s - loss: 180.4055 - val_loss: 188.3837
# Epoch 15/50
#  - 0s - loss: 174.7217 - val_loss: 183.0204
# Epoch 16/50
# ...

# %%
from sklearn.metrics import mean_squared_error
y_pred = model.predict(X_test)
mean_squared_error(y_test, y_pred)
# Out:
# 151.0670462333863

# %%
mse = []
model = regression_model_2()

for i in range(50):
    print('Iteration number: ' + str(i))
    X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3)
    model.fit(X_train, y_train, validation_split=0.3, epochs=50, verbose=2)
    y_pred = model.predict(X_test)
    mse.append(mean_squared_error(y_test, y_pred))
# Out:
# Iteration number: 0
# Train on 504 samples, validate on 217 samples
# Epoch 1/50
#  - 0s - loss: 4006.1567 - val_loss: 1780.2895
# Epoch 2/50
#  - 0s - loss: 911.0763 - val_loss: 565.7807
# Epoch 3/50
#  - 0s - loss: 414.4131 - val_loss: 384.5195
# Epoch 4/50
#  - 0s - loss: 348.2197 - val_loss: 336.6483
# Epoch 5/50
#  - 0s - loss: 325.1238 - val_loss: 314.1688
# Epoch 6/50
#  - 0s - loss: 303.6363 - val_loss: 297.9700
# Epoch 7/50
#  - 0s - loss: 282.5871 - val_loss: 285.6490
# Epoch 8/50
#  - 0s - loss: 268.8222 - val_loss: 276.0125
# Epoch 9/50
#  - 0s - loss: 257.7456 - val_loss: 263.8955
# Epoch 10/50
#  - 0s - loss: 249.7212 - val_loss: 253.2889
# Epoch 11/50
#  - 0s - loss: 240.7303 - val_loss: 247.5333
# Epoch 12/50
#  - 0s - loss: 233.4294 - val_loss: 240.5271
# Epoch 13/50
#  - 0s - loss: 225.3455 - val_loss: 231.8720
# Epoch 14/50
#  - 0s - loss: 217.3192 - val_loss: 222.7478
# Epoch 15/50
#  - 0s - loss: 208.4813 - val_loss: 216.6406
# Epoch 16/50
# ...

# %%
mean_D = np.mean(mse)
print('Mean of MSE: ', mean_D)

std_D = np.std(mse)
print('Standard Deviation of MSE:', std_D)
# Out:
# Mean of MSE:  3.300609801210558
# Standard Deviation of MSE: 16.263267956571465

# %%
#both the mean and standard deviation are extremely low in part D as compared to part B

# %%
print('\nA')
print('Mean MSE: ', mean_A)
print('Standard deviation of MSE: ', std_A)

print('\nB')
print('Mean MSE (normalized data): ', mean_B)
print('Standard deviation of MSE (normalized data): ', std_B)

print('\nC')
print('Mean MSE (normalized data, 100 epochs): ', mean_C)
print('Standard deviation of MSE (normalized data, 100 epochs): ', std_C)

print('\nD')
print('Mean MSE (normalized data, 3 hidden layers): ', mean_D)
print('Standard deviation of MSE (normalized data, 3 hidden layers): ', std_D)
# Out:
# A
# Mean MSE:  27.483412318318827
# Standard deviation of MSE:  165.79596712022925
#
# B
# Mean MSE (normalized data):  23.827472670554574
# Standard deviation of MSE (normalized data):  113.92097577860712
#
# C
# Mean MSE (normalized data, 100 epochs):  0.8712325226151825
# Standard deviation of MSE (normalized data, 100 epochs):  5.269090978358493
#
# D
# Mean MSE (normalized data, 3 hidden layers):  3.300609801210558
# Standard deviation of MSE (normalized data, 3 hidden layers):  16.263267956571465

# %%
#Normalizing the data lowered the accuracy of the model, as seen from comparison 
#of Mean and Standard deviation of MSE in parts A and B

#Doubling the number of epochs significantly improved the accuracy of the model

#Implementing 3 hidden layers instead of 1 also has increased the accuracy of the model greatly
